# %%
# Importing important modules and packages

import pandas as pd
import json
import numpy as np
import re
import warnings
from flair.models import TextClassifier
from flair.data import Sentence
import plotly.express as px
from tqdm._tqdm_notebook import tqdm_notebook
from tqdm import tqdm
warnings.filterwarnings("ignore")
tqdm_notebook.pandas()

# %% [markdown]
# <b>1. Data Collection</b>

# %%
# read data from json file
f = open('result.json', encoding='utf8')
data = json.load(f)

# %%
# load the messages into a data frame
msgs = data['messages']
df = pd.DataFrame(msgs)

# %%
df.head()
# Out:
#         id     type                 date          from         from_id  \
# 0  1903819  message  2021-05-01T00:00:12          None  user1650688285
# 1  1903842  message  2021-05-01T00:01:13          None  user1650688285
# 2  1903855  message  2021-05-01T00:01:50  Social Ch4in   user484605980
# 3  1903856  message  2021-05-01T00:02:05  Social Ch4in   user484605980
# 4  1903857  message  2021-05-01T00:02:12  Social Ch4in   user484605980
#
#                                                 text  reply_to_message_id  \
# 0                                                 hi                  NaN
# 1                                do indicators work?                  NaN
# 2  If you trade true gbp for gbp Fiat or vice Ver...                  NaN
# 3                          And how much is that fee?                  NaN
# 4                     If you’re a silver card holder                  NaN
#
#   forwarded_from actor actor_id  ... message_id file thumbnail media_type  \
# 0            NaN   NaN      NaN  ...        NaN  NaN       NaN        NaN
# 1            NaN   NaN      NaN  ...        NaN  NaN       NaN        NaN
# 2            NaN   NaN      NaN  ...        NaN  NaN       NaN        NaN
# 3            NaN   NaN      NaN  ...        NaN  NaN       NaN        NaN
# 4            NaN   NaN      NaN  ...        NaN  NaN       NaN        NaN
#
#    sticker_emoji  contact_information  contact_vcard mime_type  \
# 0            NaN                  NaN            NaN       NaN
# 1            NaN                  NaN            NaN       NaN
# 2            NaN                  NaN            NaN       NaN
# 3            NaN                  NaN            NaN       NaN
# 4            NaN                  NaN            NaN       NaN
#
#   duration_seconds via_bot
# 0              NaN     NaN
# 1              NaN     NaN
# 2              NaN     NaN
# 3              NaN     NaN
# 4              NaN     NaN
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (49436, 26)

# %% [markdown]
# - Number of text message: 49436
# - Number of attributes/columns: 26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49436 entries, 0 to 49435
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   49436 non-null  int64
#  1   type                 49436 non-null  object
#  2   date                 49436 non-null  object
#  3   from                 44854 non-null  object
#  4   from_id              49369 non-null  object
#  5   text                 49436 non-null  object
#  6   reply_to_message_id  24570 non-null  float64
#  7   forwarded_from       155 non-null    object
#  8   actor                62 non-null     object
#  9   actor_id             67 non-null     object
#  10  action               67 non-null     object
#  11  members              43 non-null     object
#  12  edited               781 non-null    object
#  13  photo                91 non-null     object
#  14  width                141 non-null    float64
#  15  height               141 non-null    float64
#  16  message_id           24 non-null     float64
#  17  file                 50 non-null     object
#  18  thumbnail            48 non-null     object
#  19  media_type           50 non-null     object
#  20  sticker_emoji        30 non-null     object
#  21  contact_information  1 non-null      object
#  22  contact_vcard        1 non-null      object
#  23  mime_type            20 non-null     object
#  24  duration_seconds     20 non-null     float64
#  25  via_bot              1 non-null      object
# dtypes: float64(5), int64(1), object(20)
# memory usage: 9.8+ MB

# %% [markdown]
# <b>2. Data Preprocessing</b>

# %%
# filter text and date column from the original dataframe
df_text = df.filter(items=['text', 'date'])

# %%
df_text.head()
# Out:
#                                                 text                 date
# 0                                                 hi  2021-05-01T00:00:12
# 1                                do indicators work?  2021-05-01T00:01:13
# 2  If you trade true gbp for gbp Fiat or vice Ver...  2021-05-01T00:01:50
# 3                          And how much is that fee?  2021-05-01T00:02:05
# 4                     If you’re a silver card holder  2021-05-01T00:02:12

# %%
df_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49436 entries, 0 to 49435
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    49436 non-null  object
#  1   date    49436 non-null  object
# dtypes: object(2)
# memory usage: 772.6+ KB

# %%
# checking if the df has any null values
df_text.isnull().sum()
# Out:
# text    0
# date    0
# dtype: int64

# %%
# standardize datetime column
df_text['date'] = pd.to_datetime(df_text['date'])

# %%
# reference: https://stackoverflow.com/a/47091490/4084039
# decontracting some english words (won't -> will not, can't -> cannot)
def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# %% [markdown]
# <b>2.1 Remove non-English messages and perform some basic text preprocessing steps</b>

# %%
# some basic text preprocessing on the text data
# 1. filter non-english messages from the text messages
# 2. convert all words to lower case
# 3. decontraction

preprocessed_text = []
for i in tqdm(range(df_text.shape[0])):
    message = re.sub('[^A-Za-z]+', ' ', str(df_text['text'][i]))
    message = ''.join(message.lower())
    message = decontracted(message)
    preprocessed_text.append(message.strip())
# Out:
# 100%|██████████| 49436/49436 [00:00<00:00, 63911.83it/s]

# %%
df_text['text'] = preprocessed_text

# %%
df_text.head()
# Out:
#                                                 text                date
# 0                                                 hi 2021-05-01 00:00:12
# 1                                 do indicators work 2021-05-01 00:01:13
# 2  if you trade true gbp for gbp fiat or vice ver... 2021-05-01 00:01:50
# 3                           and how much is that fee 2021-05-01 00:02:05
# 4                     if you re a silver card holder 2021-05-01 00:02:12

# %%
df_prep1 = df_text.copy()

# %%
# replace blank space with nan values
df_prep1.replace('', np.nan, inplace=True)

# %%
# check null values
df_prep1.isnull().sum()
# Out:
# text    1583
# date       0
# dtype: int64

# %%
# drop na values
df_prep1 = df_prep1.dropna()

# %%
df_prep1.shape
# Out:
# (47853, 2)

# %%
df_prep1.isnull().sum()
# Out:
# text    0
# date    0
# dtype: int64

# %%
df_prep1.isna().sum()
# Out:
# text    0
# date    0
# dtype: int64

# %% [markdown]
# <b>2.2 Keep only messages that mention either “SHIB” or “DOGE.</b>

# %%
def include_words(s):
    s_l = s['text']
    if 'shib' in s_l or 'doge' in s_l:
        return True
    else:
        return False

# %%
s_l = []
for i in tqdm(range(df_prep1.shape[0])):
    s_l.append(include_words(df_prep1.iloc[i]))
# Out:
# 100%|██████████| 47853/47853 [00:03<00:00, 14871.32it/s]

# %%
df_prep1 = df_prep1.loc[s_l, ['text', 'date']]

# %%
df_prep1.head()
# Out:
#                                                  text                date
# 63                                 doge is going cray 2021-05-01 00:56:05
# 66                                sell target of doge 2021-05-01 00:57:07
# 68                                               doge 2021-05-01 00:58:11
# 72                                  dogecoin que hago 2021-05-01 00:59:29
# 74  anyway is doge a good crypto for long term inv... 2021-05-01 01:00:32

# %%
df_prep1.shape
# Out:
# (3061, 2)

# %%
df_sent = df_prep1.copy()

# %%
df_sent.head()
# Out:
#                                                  text                date
# 63                                 doge is going cray 2021-05-01 00:56:05
# 66                                sell target of doge 2021-05-01 00:57:07
# 68                                               doge 2021-05-01 00:58:11
# 72                                  dogecoin que hago 2021-05-01 00:59:29
# 74  anyway is doge a good crypto for long term inv... 2021-05-01 01:00:32

# %%
df_sent.shape
# Out:
# (3061, 2)

# %% [markdown]
# <b>3. Sentiment Analysis</b>

# %%
# load the pre-trained flair model
flair_sa = TextClassifier.load('en-sentiment')
# Out:
# 2021-12-18 08:40:33,023 loading file /Users/amitsingh/.flair/models/sentiment-en-mix-distillbert_4.pt

# %%
# extracting sentiment score and the corresponding sentiment value for each message

s_score = []
s_score_norm = []
s_sentiment = []

for sentence in tqdm(df_sent["text"]):
    sentence = Sentence(sentence)
    flair_sa.predict(sentence)
    if sentence.labels[0].value.startswith("POS"):
        sentence.labels[0].score *= 1
        s_score_norm.append(1)
    else:
        sentence.labels[0].score *= -1
        s_score_norm.append(-1)
    s_score.append(sentence.labels[0].score)
    s_sentiment.append(sentence.labels[0].value)
# Out:
# 100%|██████████| 3061/3061 [03:13<00:00, 15.80it/s]

# %%
df_sent['s_score'] = s_score
df_sent['s_score_norm'] = s_score_norm
df_sent['s_sentiment'] = s_sentiment

# %%
df_sent
# Out:
#                                                     text                date  \
# 63                                    doge is going cray 2021-05-01 00:56:05
# 66                                   sell target of doge 2021-05-01 00:57:07
# 68                                                  doge 2021-05-01 00:58:11
# 72                                     dogecoin que hago 2021-05-01 00:59:29
# 74     anyway is doge a good crypto for long term inv... 2021-05-01 01:00:32
# ...                                                  ...                 ...
# 49376                                        how is shib 2021-05-15 23:28:18
# 49384                                        how is shib 2021-05-15 23:31:14
# 49390  shiba swap is gonna launch soon it will defini... 2021-05-15 23:32:55
# 49408  whole crypto market is being dominated by bear... 2021-05-15 23:38:34
# 49428                           any one belives in shiba 2021-05-15 23:55:27
#
#         s_score  s_score_norm s_sentiment
# 63    -0.998401            -1    NEGATIVE
# 66    -0.987667            -1    NEGATIVE
# 68    -0.712615            -1    NEGATIVE
# 72    -0.602185            -1    NEGATIVE
# 74    -0.535006            -1    NEGATIVE
# ...         ...           ...         ...
# 49376 -0.804514            -1    NEGATIVE
# 49384 -0.804514            -1    NEGATIVE
# 49390  0.794794             1    POSITIVE
# 49408 -0.999967            -1    NEGATIVE
# 49428 -0.758289            -1    NEGATIVE
#
# [3061 rows x 5 columns]

# %%
df_sent.isnull().sum()
# Out:
# text            0
# date            0
# s_score         0
# s_score_norm    0
# s_sentiment     0
# dtype: int64

# %%
df_sent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3061 entries, 63 to 49428
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text          3061 non-null   object
#  1   date          3061 non-null   datetime64[ns]
#  2   s_score       3061 non-null   float64
#  3   s_score_norm  3061 non-null   int64
#  4   s_sentiment   3061 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 143.5+ KB

# %%
df_sent.describe()
# Out:
#            s_score  s_score_norm
# count  3061.000000   3061.000000
# mean     -0.300625     -0.311990
# std       0.880799      0.950241
# min      -0.999998     -1.000000
# 25%      -0.998227     -1.000000
# 50%      -0.922572     -1.000000
# 75%       0.868488      1.000000
# max       0.999954      1.000000

# %%
df_sent['s_score'].describe()
# Out:
# count    3061.000000
# mean       -0.300625
# std         0.880799
# min        -0.999998
# 25%        -0.998227
# 50%        -0.922572
# 75%         0.868488
# max         0.999954
# Name: s_score, dtype: float64

# %%
df_sent['s_sentiment'].value_counts()
# Out:
# NEGATIVE    2008
# POSITIVE    1053
# Name: s_sentiment, dtype: int64

# %% [markdown]
# - Number of positive messages: 2008
# - Number of negative messages: 1053

# %%
df_viz = df_sent.copy()

# %% [markdown]
# <b>4. Visualization</b>

# %%
df_viz.head()
# Out:
#                                                  text                date  \
# 63                                 doge is going cray 2021-05-01 00:56:05
# 66                                sell target of doge 2021-05-01 00:57:07
# 68                                               doge 2021-05-01 00:58:11
# 72                                  dogecoin que hago 2021-05-01 00:59:29
# 74  anyway is doge a good crypto for long term inv... 2021-05-01 01:00:32
#
#      s_score  s_score_norm s_sentiment
# 63 -0.998401            -1    NEGATIVE
# 66 -0.987667            -1    NEGATIVE
# 68 -0.712615            -1    NEGATIVE
# 72 -0.602185            -1    NEGATIVE
# 74 -0.535006            -1    NEGATIVE

# %%
# adding a new column to contain the absolute sentiment score
df_viz['s_score_abs'] = df_viz['s_score'].abs()

# %%
# adding a new column to contain day
df_viz['day'] = df_viz['date'].dt.floor('d').astype('str')

# %%
df_viz.head()
# Out:
#                                                  text                date  \
# 63                                 doge is going cray 2021-05-01 00:56:05
# 66                                sell target of doge 2021-05-01 00:57:07
# 68                                               doge 2021-05-01 00:58:11
# 72                                  dogecoin que hago 2021-05-01 00:59:29
# 74  anyway is doge a good crypto for long term inv... 2021-05-01 01:00:32
#
#      s_score  s_score_norm s_sentiment  s_score_abs         day
# 63 -0.998401            -1    NEGATIVE     0.998401  2021-05-01
# 66 -0.987667            -1    NEGATIVE     0.987667  2021-05-01
# 68 -0.712615            -1    NEGATIVE     0.712615  2021-05-01
# 72 -0.602185            -1    NEGATIVE     0.602185  2021-05-01
# 74 -0.535006            -1    NEGATIVE     0.535006  2021-05-01

# %%
df_viz['day'].unique()
# Out:
# array(['2021-05-01', '2021-05-02', '2021-05-03', '2021-05-04',
#        '2021-05-05', '2021-05-06', '2021-05-07', '2021-05-08',
#        '2021-05-09', '2021-05-10', '2021-05-11', '2021-05-12',
#        '2021-05-13', '2021-05-14', '2021-05-15'], dtype=object)

# %% [markdown]
# <b> 4.1 Plot-1: Number of messages per day

# %%
fig = px.bar(df_viz, x='day',
             labels={
                     "day": "Day",
                     "count": "Number of messages"
             },
             title="Number of messages per day", height=600, width=800)
fig.update_traces(marker_color='green')
fig.show()
# Out:
# <div>                            <div id="ffd7aa20-6ce8-4338-8a35-2930c5ffc3ff" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffd7aa20-6ce8-4338-8a35-2930c5ffc3ff")) {                    Plotly.newPlot(                        "ffd7aa20-6ce8-4338-8a35-2930c5ffc3ff",                        [{"alignmentgroup":"True","hovertemplate":"Day=%{x}<br>Number of messages=%{y}<extra></extra>","legendgroup":"","marker":{"color":"green","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-01","2021-05-02","2021-05-02","2021-05-02","2021-05-02","2021-05-02","2021-05-02","2021-05-02","2021-05-02","2021-05-02","2021-05-02","2021-05-02","2021-05-02","2021-05-02","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-03","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-04","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021-05-05","2021 ...

# %%
# number of message per day
df_msg_day = df_viz.groupby(df_viz['date'].
                            dt.floor('d')).size().reset_index(name='count')
print(df_msg_day)
# Out:
#          date  count
# 0  2021-05-01     48
# 1  2021-05-02     13
# 2  2021-05-03     29
# 3  2021-05-04    120
# 4  2021-05-05     96
# 5  2021-05-06     72
# 6  2021-05-07    135
# 7  2021-05-08    709
# 8  2021-05-09    274
# 9  2021-05-10    773
# 10 2021-05-11    249
# 11 2021-05-12    159
# 12 2021-05-13    198
# 13 2021-05-14    109
# 14 2021-05-15     77

# %% [markdown]
# <b> 4.2 Plot-2: Average sentiment per day

# %%
# group by day and sentiment value
df_avg = df_viz.groupby(['day', 's_sentiment']).s_score.mean()

# %%
df_avg
# Out:
# day         s_sentiment
# 2021-05-01  NEGATIVE      -0.888683
#             POSITIVE       0.905570
# 2021-05-02  NEGATIVE      -0.863493
#             POSITIVE       0.881267
# 2021-05-03  NEGATIVE      -0.939170
#             POSITIVE       0.800103
# 2021-05-04  NEGATIVE      -0.882520
#             POSITIVE       0.921779
# 2021-05-05  NEGATIVE      -0.881150
#             POSITIVE       0.849102
# 2021-05-06  NEGATIVE      -0.928971
#             POSITIVE       0.867700
# 2021-05-07  NEGATIVE      -0.906430
#             POSITIVE       0.894220
# 2021-05-08  NEGATIVE      -0.942209
#             POSITIVE       0.905271
# 2021-05-09  NEGATIVE      -0.938643
#             POSITIVE       0.891866
# 2021-05-10  NEGATIVE      -0.953251
#             POSITIVE       0.913839
# 2021-05-11  NEGATIVE      -0.922029
#             POSITIVE       0.903521
# 2021-05-12  NEGATIVE      -0.912773
#             POSITIVE       0.902480
# 2021-05-13  NEGATIVE      -0.913261
#             POSITIVE       0.891222
# 2021-05-14  NEGATIVE      -0.932655
#             POSITIVE       0.920729
# 2021-05-15  NEGATIVE      -0.929976
#             POSITIVE       0.945538
# Name: s_score, dtype: float64

# %%
df_avg = df_avg.to_frame().reset_index()

# %%
fig = px.bar(df_avg, x="day", y='s_score', color='s_sentiment',
             labels={
                     "day": "Day",
                     "s_score": "Sentiment Score",
                     "s_sentiment": "Sentiment"
                 },
             title=" Average sentiment per day",
             barmode='group', height=400, width=1000)
fig.show()
# Out:
# <div>                            <div id="437ad885-bbbf-4a3f-82a8-b3259bdcaceb" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("437ad885-bbbf-4a3f-82a8-b3259bdcaceb")) {                    Plotly.newPlot(                        "437ad885-bbbf-4a3f-82a8-b3259bdcaceb",                        [{"alignmentgroup":"True","hovertemplate":"Sentiment=NEGATIVE<br>Day=%{x}<br>Sentiment Score=%{y}<extra></extra>","legendgroup":"NEGATIVE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"NEGATIVE","offsetgroup":"NEGATIVE","orientation":"v","showlegend":true,"textposition":"auto","x":["2021-05-01","2021-05-02","2021-05-03","2021-05-04","2021-05-05","2021-05-06","2021-05-07","2021-05-08","2021-05-09","2021-05-10","2021-05-11","2021-05-12","2021-05-13","2021-05-14","2021-05-15"],"xaxis":"x","y":[-0.8886832577841622,-0.8634931743144989,-0.939170303940773,-0.8825196068029146,-0.8811500370502472,-0.9289709779451478,-0.906430203593179,-0.9422089905809548,-0.9386425469860886,-0.9532514705107762,-0.9220291972160339,-0.9127731589710011,-0.9132609793899256,-0.9326553372236398,-0.929975523668177],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=POSITIVE<br>Day=%{x}<br>Sentiment Score=%{y}<extra></extra>","legendgroup":"POSITIVE","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"POSITIVE","offsetgroup":"POSITIVE","orientation":"v","showlegend":true,"textposition":"auto","x":["2021-05-01","2021-05-02","2021-05-03","2021-05-04","2021-05-05","2021-05-06","2021-05-07","2021-05-08","2021-05-09","2021-05-10","2021-05-11","2021-05-12","2021-05-13","2021-05-14","2021-05-15"],"xaxis":"x","y":[0.9055699155880854,0.8812665104866028,0.8001033729977078,0.9217794084030649,0.8491015732288361,0.8677003226782146,0.8942200113897738,0.9052710113143116,0.8918660463471162,0.9138385540411877,0.9035209543175168,0.9024801971139135,0.8912222867601374,0.9207293160937049,0.945538213619819],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666666 ...
